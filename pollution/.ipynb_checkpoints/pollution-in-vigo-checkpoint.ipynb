# %%
import requests
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
from datetime import date, timedelta

# %%
sdate = date(2017, 1, 1)   # start date
#edate = date.today()      # end date

edate = date.today()  # end date

delta = edate - sdate      # as timedelta

date_list = []
for i in range(delta.days + 1):
    day = sdate + timedelta(days=i)
    date_list.append(day.strftime("%d/%m/%Y"))
    
date_list[:5]
# Out:
# ['01/01/2017', '02/01/2017', '03/01/2017', '04/01/2017', '05/01/2017']

# %%
json_list = []
for day in date_list:
    payload = {'idZona':'7',
               'data':day}
    r = requests.get('http://servizos.meteogalicia.es/rss/observacion/listaEstacionsCA.action',
                 params=payload)
    json_list.append(r.json())

# %%
for i, json_file in enumerate(json_list):
    fecha = json_file['datosZona'][0]['fecha']
    formatted_fecha = pd.to_datetime(fecha, dayfirst=True).date()
    filename = "./jsons/dia_{}.json".format(formatted_fecha)
    with open(filename, 'w') as open_file:
        json.dump(json_file, open_file)

# %%
def read_day(day):
    pass

def read_hour(hour):
    meas_dict = {
        ('Vigo - Coia', 'SO2'):'SO2_c',
        ('Vigo - Coia', 'SO2'):'CO2_c',
        ('Vigo - Coia', 'SO2'):'NO2_c',
        ('Vigo - Coia', 'SO2'):'PM10_c',
        ('Vigo - Coia', 'SO2'):'O3_c',
        ('Vigo - Lope de Vega', 'SO2'):'SO2_ldv',
        ('Vigo - Lope de Vega', 'SO2'):'CO2_ldv',
        ('Vigo - Lope de Vega', 'SO2'):'NO2_ldv',
        ('Vigo - Lope de Vega', 'SO2'):'PM10_ldv',
        ('Vigo - Lope de Vega', 'SO2'):'O3_ldv'
    }
    for ica in hour['icas']:
        print(meas_dict[(ica['estacion'], ica['parametro'])])
        
read_hour(json_list[125]['datosZona'][0])
print()
read_hour(json_list[84]['datosZona'][9])
# Out:
# Vigo - Coia SO2
# Vigo - Coia CO
# Vigo - Coia NO2
# Vigo - Coia PM10
# Vigo - Coia O3
#
# Vigo - Lope de Vega NO2
# Vigo - Lope de Vega PM10
# Vigo - Lope de Vega O3
# Vigo - Coia NO2
# Vigo - Coia PM10
# Vigo - Coia O3
# Vigo - Coia SO2
# Vigo - Coia CO
# Vigo - Coia NO2
# Vigo - Coia PM10
# Vigo - Coia O3
# Vigo - Lope de Vega SO2
# Vigo - Lope de Vega CO
# Vigo - Lope de Vega NO2
# Vigo - Lope de Vega PM10
# Vigo - Lope de Vega O3

# %%
json_list[0]['datosZona'][0]
# Out:
# {'fecha': '01/01/2017',
#  'hora': '13:00',
#  'icas': [{'calculo': 'H',
#    'estacion': 'Vigo - Coia',
#    'fecha': '01/01/2017',
#    'hora': '13:00',
#    'parametro': 'SO2',
#    'textoValor': 'Boa',
#    'valor': '0',
#    'valorIca': '0.01'},
#   {'calculo': 'O',
#    'estacion': 'Vigo - Coia',
#    'fecha': '01/01/2017',
#    'hora': '13:00',
#    'parametro': 'CO',
#    'textoValor': 'Boa',
#    'valor': '0',
#    'valorIca': '0.028'},
#   {'calculo': 'H',
#    'estacion': 'Vigo - Coia',
#    'fecha': '01/01/2017',
#    'hora': '13:00',
#    'parametro': 'NO2',
#    'textoValor': 'Boa',
#    'valor': '0',
#    'valorIca': '0.19'},
#   {'calculo': 'H',
#    'estacion': 'Vigo - Coia',
#    'fecha': '01/01/2017',
#    'hora': '13:00',
#    'parametro': 'PM10',
#    'textoValor': 'Boa',
#    'valor': '0',
#    'valorIca': '0.36'},
#   {'calculo': 'H',
#    'estacion': 'Vigo - Coia',
#    'fecha': '01/01/2017',
#    'hora': '13:00',
#    'parametro': 'O3',
#    'textoValor': 'Boa',
#    'valor': '0',
#    'valorIca': '0.17'},
#   {'calculo': 'H',
#    'estacion': 'Vigo - Lope de Vega',
#    'fecha': '01/01/2017',
#    'hora': '13:00',
#    'parametro': 'SO2',
#    'textoValor': 'Boa',
#    'valor': '0',
#    'valorIca': '0.0'},
#   {'calculo': 'O',
#    'estacion': 'Vigo - Lope de Vega',
#    'fecha': '01/01/2017',
#    'hora': '13:00',
#    'parametro': 'CO',
#    'textoValor': 'Boa',
#    'valor': '0',
#    'valorIca': '0.039'},
#   {'calculo': 'H',
#    'estacion': 'Vigo - Lope de Vega',
#    'fecha': '01/01/2017',
#    'hora': '13:00',
#    'parametro': 'NO2',
#    'textoValor': 'Boa',
#    'valor': '0',
#    'valorIca': '0.27'},
#   {'calculo': 'H',
#    'estacion': 'Vigo - Lope de Vega',
#    'fecha': '01/01/2017',
#    'hora': '13:00',
#    'parametro': 'PM10',
#    'textoValor': 'Boa',
#    'valor': '0',
#    'valorIca': '0.24'},
#   {'calculo': 'H',
#    'estacion': 'Vigo - Lope de Vega',
#    'fecha': '01/01/2017',
#    'hora': '13:00',
#    'parametro': 'O3',
#    'textoValor': 'Boa',
#    'valor': '0',
#    'valorIca': '0.16'}],
#  'idZona': '7',
#  'lat': '42.219002',
#  'lon': '-8.742058',
#  'textoValor': 'Boa',
#  'valor': '0',
#  'valorIca': '0.36',
#  'zona': 'Vigo'}

# %%
#for json_file in json_list:
#    for hour in json_file['datosZona']:
#        ica_pairs = [(ica['estacion'], ica['parametro']) for ica in hour['icas']]
#        print(ica_pairs)
#        #hour['icas'] = [i for n, i in enumerate(hour['icas']) if i not in hour['icas'][n + 1:]]

# %%
def get_values(hour):
    value_list = []
    ica_pair_list = []
    for ica in hour['icas']:
        try:
            ica_pair = (ica['estacion'], ica['parametro'])
            if ica_pair not in ica_pair_list:
                value_list.append(float(ica['valorIca']))
                ica_pair_list.append(ica_pair)
            else:
                pass
        except:
            value_list.append(np.nan)
    return np.array(value_list)

def get_mean(day):
    value_list = []
    for hour in day:
        value_list.append(get_values(hour))
    try:
        return np.mean(np.array(value_list), axis=0)
    except TypeError:
        return value_list

# %%
json_list[84]['datosZona'][9]['icas']
get_values(json_list[125]['datosZona'][0])
json_list[125]['datosZona'][0]
# Out:
# {'fecha': '06/05/2017',
#  'hora': '13:00',
#  'icas': [{'calculo': 'H',
#    'estacion': 'Vigo - Coia',
#    'fecha': '06/05/2017',
#    'hora': '13:00',
#    'parametro': 'SO2',
#    'textoValor': 'Boa',
#    'valor': '0',
#    'valorIca': '0.01'},
#   {'calculo': 'O',
#    'estacion': 'Vigo - Coia',
#    'fecha': '06/05/2017',
#    'hora': '13:00',
#    'parametro': 'CO',
#    'textoValor': 'Boa',
#    'valor': '0',
#    'valorIca': '0.04'},
#   {'calculo': 'H',
#    'estacion': 'Vigo - Coia',
#    'fecha': '06/05/2017',
#    'hora': '13:00',
#    'parametro': 'NO2',
#    'textoValor': 'Boa',
#    'valor': '0',
#    'valorIca': '0.27'},
#   {'calculo': 'H',
#    'estacion': 'Vigo - Coia',
#    'fecha': '06/05/2017',
#    'hora': '13:00',
#    'parametro': 'PM10',
#    'textoValor': 'Boa',
#    'valor': '0',
#    'valorIca': '0.15'},
#   {'calculo': 'H',
#    'estacion': 'Vigo - Coia',
#    'fecha': '06/05/2017',
#    'hora': '13:00',
#    'parametro': 'O3',
#    'textoValor': 'Boa',
#    'valor': '0',
#    'valorIca': '0.41'}],
#  'idZona': '7',
#  'lat': '42.219002',
#  'lon': '-8.742058',
#  'textoValor': 'Boa',
#  'valor': '0',
#  'valorIca': '0.41',
#  'zona': 'Vigo'}

# %%
for i, day in enumerate(json_list):
    try:
        get_mean(day['datosZona'])
    except:
        print(i)
# Out:
# 125
# 127
# 437
# 438
# 442
# 448
# 449
# 461
# 463
# 676
# 729
# 772
# 807
# 808
# 924
# 925
# 959
# 960
# 976
# 978
# 979
# 981
# 993
# 995

# %%
for meas in json_list[-1]['datosZona'][0]['icas']:
    print(meas['parametro'], meas['estacion'])
# Out:
# SO2 Vigo - Coia
# CO Vigo - Coia
# NO2 Vigo - Coia
# PM10 Vigo - Coia
# O3 Vigo - Coia
# SO2 Vigo - Lope de Vega
# CO Vigo - Lope de Vega
# NO2 Vigo - Lope de Vega
# PM10 Vigo - Lope de Vega
# O3 Vigo - Lope de Vega

# %%
raw_data = []
dates = []
for i, day in enumerate(json_list):
    try:
        row = get_mean(day['datosZona'])
        raw_data.append(row)
        dates.append(json_list[i]['datosZona'][0]['fecha'])
    except TypeError:
        print("{} failed".format(i))
    #row = []
    #row.append(json_list[i]['datosZona'][0]['fecha'])
    #for meas in json_list[i]['datosZona'][0]['icas']:
    #    [x for x in json_list[i]['datosZona']]
    #    row.append(meas['valorIca'])
    #row.insert(0, json_list[i]['datosZona'][0]['fecha'])

print(len(dates))
print(len(raw_data))
    
df = pd.DataFrame(raw_data,
                  columns=[
                     'SO2_c',
                     'CO2_c',
                     'NO2_c',
                     'PM10_c',
                     'O3_c',
                     'SO2_ldv',
                     'CO2_ldv',
                     'NO2_ldv',
                     'PM10_ldv',
                     'O3_ldv',
                     ],
                    dtype='float')
df.insert(0, 'data', pd.to_datetime(dates, dayfirst=True))
df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-114-5f3746195f56> in <module>
#       3 for i, day in enumerate(json_list):
#       4     try:
# ----> 5         row = get_mean(day['datosZona'])
#       6         raw_data.append(row)
#       7         dates.append(json_list[i]['datosZona'][0]['fecha'])
#
# <ipython-input-110-1a0f3e9c2ef7> in get_mean(day)
#      13         value_list.append(get_values(hour))
#      14     try:
# ---> 15         return np.mean(np.array(value_list), axis=0)
#      16     except TypeError:
#      17         return value_list
#
# <__array_function__ internals> in mean(*args, **kwargs)
#
# ~/miniconda3/envs/data/lib/python3.8/site-packages/numpy/core/fromnumeric.py in mean(a, axis, dtype, out, keepdims)
#    3254             return mean(axis=axis, dtype=dtype, out=out, **kwargs)
#    3255
# -> 3256     return _methods._mean(a, axis=axis, dtype=dtype,
#    3257                           out=out, **kwargs)
#    3258
#
# ~/miniconda3/envs/data/lib/python3.8/site-packages/numpy/core/_methods.py in _mean(a, axis, dtype, out, keepdims)
#     149             is_float16_result = True
#     150
# --> 151     ret = umr_sum(arr, axis, dtype, out, keepdims)
#     152     if isinstance(ret, mu.ndarray):
#     153         ret = um.true_divide(
#
# ValueError: operands could not be broadcast together with shapes (10,) (16,)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1148 entries, 0 to 1147
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   data      1148 non-null   datetime64[ns]
#  1   SO2_c     1148 non-null   float64
#  2   CO2_c     1148 non-null   float64
#  3   NO2_c     1148 non-null   float64
#  4   PM10_c    1148 non-null   float64
#  5   O3_c      1148 non-null   float64
#  6   SO2_ldv   1142 non-null   float64
#  7   CO2_ldv   1142 non-null   float64
#  8   NO2_ldv   1142 non-null   float64
#  9   PM10_ldv  1142 non-null   float64
#  10  O3_ldv    1140 non-null   float64
# dtypes: datetime64[ns](1), float64(10)
# memory usage: 98.8 KB

# %%
for col in df.columns[1:]:
    df.loc[df[col] <= 0, col] = None
df.interpolate()
df.fillna(df.mean(), inplace=True)
df
# Out:
#            data    SO2_c    CO2_c    NO2_c   PM10_c     O3_c  SO2_ldv  \
# 0    2017-01-01  0.00768  0.04672  0.31120  0.52840  0.13620  0.00704
# 1    2017-01-02  0.00492  0.03124  0.22560  0.25772  0.21320  0.00404
# 2    2017-01-03  0.00444  0.01968  0.17980  0.14408  0.32560  0.00400
# 3    2017-01-04  0.00344  0.02828  0.23832  0.13704  0.17344  0.00296
# 4    2017-01-05  0.00476  0.03992  0.29160  0.20548  0.07952  0.00424
# ...         ...      ...      ...      ...      ...      ...      ...
# 1143 2020-03-17  0.01376  0.01396  0.08008  0.11596  0.43324  0.01224
# 1144 2020-03-18  0.01784  0.02164  0.12620  0.15104  0.29012  0.01780
# 1145 2020-03-19  0.02356  0.02128  0.15120  0.25436  0.21064  0.02232
# 1146 2020-03-20  0.01932  0.01444  0.04648  0.25000  0.41360  0.01800
# 1147 2020-03-21  0.01916  0.01464  0.07656  0.17080  0.30480  0.01900
#
#       CO2_ldv  NO2_ldv  PM10_ldv   O3_ldv
# 0     0.04724  0.31240   0.45800  0.13992
# 1     0.03196  0.22920   0.24716  0.20980
# 2     0.02024  0.17952   0.14216  0.31480
# 3     0.02864  0.24000   0.13772  0.16576
# 4     0.04092  0.28840   0.20480  0.08168
# ...       ...      ...       ...      ...
# 1143  0.01416  0.07992   0.11136  0.42708
# 1144  0.02172  0.13052   0.14760  0.28744
# 1145  0.02156  0.14488   0.25124  0.21592
# 1146  0.01448  0.04500   0.24440  0.41440
# 1147  0.01468  0.06900   0.16880  0.30240
#
# [1148 rows x 11 columns]

# %%
df.to_csv('./since_2017.csv')

# %%
gas = 'CO2_c'
fig, ax = plt.subplots(figsize=(10,8))
ax = sns.lineplot(data=df[df['data'].dt.year == 2017], x=range(365), y=gas, color='grey')
ax = sns.lineplot(data=df[df['data'].dt.year == 2018], x=range(365), y=gas, color='grey')
ax = sns.lineplot(data=df[df['data'].dt.year == 2019], x=range(365), y=gas, color='grey')
ax = sns.lineplot(data=df[df['data'].dt.year == 2020], x=range(df[df['data'].dt.year == 2020].shape[0]),
                  y=gas, color='red')
ax.set_ylim(-0.1, 0.1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-82-dbcc56fc2751> in <module>
#       1 gas = 'CO2_c'
#       2 fig, ax = plt.subplots(figsize=(10,8))
# ----> 3 ax = sns.lineplot(data=df[df['data'].dt.year == 2017], x=range(365), y=gas, color='grey')
#       4 ax = sns.lineplot(data=df[df['data'].dt.year == 2018], x=range(365), y=gas, color='grey')
#       5 ax = sns.lineplot(data=df[df['data'].dt.year == 2019], x=range(365), y=gas, color='grey')
#
# ~/miniconda3/envs/data/lib/python3.8/site-packages/seaborn/relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#    1123              legend="brief", ax=None, **kwargs):
#    1124
# -> 1125     p = _LinePlotter(
#    1126         x=x, y=y, hue=hue, size=size, style=style, data=data,
#    1127         palette=palette, hue_order=hue_order, hue_norm=hue_norm,
#
# ~/miniconda3/envs/data/lib/python3.8/site-packages/seaborn/relational.py in __init__(self, x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend)
#     697                  sort=True, err_style=None, err_kws=None, legend=None):
#     698
# --> 699         plot_data = self.establish_variables(
#     700             x, y, hue, size, style, units, data
#     701         )
#
# ~/miniconda3/envs/data/lib/python3.8/site-packages/seaborn/relational.py in establish_variables(self, x, y, hue, size, style, units, data)
#     155                 units=units
#     156             )
# --> 157             plot_data = pd.DataFrame(plot_data)
#     158
#     159         # Option 3:
#
# ~/miniconda3/envs/data/lib/python3.8/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     433             )
#     434         elif isinstance(data, dict):
# --> 435             mgr = init_dict(data, index, columns, dtype=dtype)
#     436         elif isinstance(data, ma.MaskedArray):
#     437             import numpy.ma.mrecords as mrecords
#
# ~/miniconda3/envs/data/lib/python3.8/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     252             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     253         ]
# --> 254     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     255
#     256
#
# ~/miniconda3/envs/data/lib/python3.8/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      62     # figure out the index, if necessary
#      63     if index is None:
# ---> 64         index = extract_index(arrays)
#      65     else:
#      66         index = ensure_index(index)
#
# ~/miniconda3/envs/data/lib/python3.8/site-packages/pandas/core/internals/construction.py in extract_index(data)
#     376                         f"length {len(index)}"
#     377                     )
# --> 378                     raise ValueError(msg)
#     379             else:
#     380                 index = ibase.default_index(lengths[0])
#
# ValueError: array length 365 does not match index length 361
